# %%
import pandas as pd
movie=pd.read_csv('data/movie.csv')
movie.head(3)
index=movie.index
columns=movie.columns
data=movie.values

type(index)
type(columns)

columns.values

#use dtypes attribute to display each column along with its data type.
movie.dtypes
movie.get_dtype_counts()

s_attr_methods=set(dir(pd.Series)) #get all attributes and methonds of a Series and 创建一个集合 as directonary
len(s_attr_methods)
# Out:
# 464

# %%
#Series is a single column from a dataframe, just an index and the data
movie['director_name']
movie.director_name
type(movie['director_name'])

director=movie['director_name']
facebook_like=movie['director_facebook_likes']

director.value_counts() #counts all the occurrences of each unique value
director.count() #count number of non-missing value
director.size  #count number of elements in the Series
len(director)  #count number of elements in the Series
#facebook_like.mean()
#facebook_like.median()
facebook_like.describe()

facebook_like.quantile([.1,.2,.3,.8,.9]) #25%分位数

director.isnull()  #notnull()
actor_1_fb_like_filled=facebook_like.fillna(0) #replace all missing values within a Seris with fillna
actor_1_fb_like_dropped=facebook_like.dropna() #remove the series elements with missing values

director.value_counts(normalize=True) #return the percentage of total distribution
facebook_like.hasnans #determine if the series has NaN
# Out:
# True

# %%
imdb_score=movie['imdb_score']
imdb_score-1  #imdb_scrore.sub(1)
imdb_score//7 #取整 imdb_score.floordiv(7)
imdb_score%6 #取余  imdb_score.mod(6)
# Out:
# 0       1.9
# 1       1.1
# 2       0.8
# 3       2.5
# 4       1.1
# 5       0.6
# 6       0.2
# 7       1.8
# 8       1.5
# 9       1.5
# 10      0.9
# 11      0.1
# 12      0.7
# 13      1.3
# 14      0.5
# 15      1.2
# 16      0.6
# 17      2.1
# 18      0.7
# 19      0.8
# 20      1.5
# 21      1.0
# 22      0.7
# 23      1.9
# 24      0.1
# 25      1.2
# 26      1.7
# 27      2.2
# 28      5.9
# 29      1.0
#        ...
# 4886    1.0
# 4887    0.3
# 4888    1.1
# 4889    4.8
# 4890    3.3
# 4891    0.9
# 4892    4.6
# 4893    3.0
# 4894    0.6
# 4895    1.4
# 4896    0.2
# 4897    4.0
# 4898    0.1
# 4899    0.9
# 4900    1.5
# 4901    0.7
# 4902    1.4
# 4903    0.1
# 4904    5.4
# 4905    0.4
# 4906    1.0
# 4907    0.3
# 4908    0.9
# 4909    1.8
# 4910    0.4
# 4911    1.7
# 4912    1.5
# 4913    0.3
# 4914    0.3
# 4915    0.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
#Chaining Series method together
director=movie['director_name']
facebook_like=movie['director_facebook_likes']

director.value_counts().head(3)
director.isnull().sum()
facebook_like.fillna(0)\
             .astype(int)\
             .head()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 4886    False
# 4887    False
# 4888    False
# 4889    False
# 4890    False
# 4891    False
# 4892    False
# 4893    False
# 4894    False
# 4895    False
# 4896    False
# 4897    False
# 4898    False
# 4899    False
# 4900    False
# 4901    False
# 4902    False
# 4903    False
# 4904    False
# 4905    False
# 4906    False
# 4907    False
# 4908    False
# 4909    False
# 4910    False
# 4911    False
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# ...

# %%
#Making the index meaningful
moive_new=pd.read_csv('data/movie.csv')
moive_new2=moive_new.set_index('movie_title')
# or you can do movie_new=pd.read_csv('data/movie.csv',index_col='movie_title')
moive_new2.reset_index() #reset to default RangeIndex

#Renaming row and column names
#datafram rename method accept directionaries that map the old value to new value
index_rename={'Avatar':'Ratava','Spectre':'Ertceps'}
col_rename={'director_name':'Director_Name'}
movie_renamed=moive_new2.rename(index=index_rename,columns=col_rename)
movie_renamed.head()
# Out:
#                                             color      Director_Name  \
# movie_title
# Ratava                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Ertceps                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Ratava                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Ertceps                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
#renaming index and column using list
movie3=pd.read_csv('data/movie.csv',index_col='movie_title')
index=movie3.index
columns=movie3.columns
index_list=index.tolist()
columns_list=columns.tolist()
#rename the row and column with list assignment
index_list[0]='Fukcer'
columns_list[1]='My_Director_Name'
movie3.index=index_list
movie3.columns=columns_list
movie3
# Out:
#                                                        color  \
# Fukcer                                                 Color
# Pirates of the Caribbean: At World's End               Color
# Spectre                                                Color
# The Dark Knight Rises                                  Color
# Star Wars: Episode VII - The Force Awakens               NaN
# John Carter                                            Color
# Spider-Man 3                                           Color
# Tangled                                                Color
# Avengers: Age of Ultron                                Color
# Harry Potter and the Half-Blood Prince                 Color
# Batman v Superman: Dawn of Justice                     Color
# Superman Returns                                       Color
# Quantum of Solace                                      Color
# Pirates of the Caribbean: Dead Man's Chest             Color
# ...

# %%
#Creating and Deleting columns
movie=pd.read_csv('data/movie.csv')
movie['has_seen']=0 #easiest way to add a column
movie['actor_director_facebook_likes']=(movie['actor_1_facebook_likes']+
                                      movie['actor_2_facebook_likes']+
                                      movie['actor_3_facebook_likes']+
                                      movie['director_facebook_likes'])
movie['actor_director_facebook_likes'].isnull().sum()
movie['actor_director_facebook_likes']=movie['actor_director_facebook_likes'].fillna(0)

movie['actor_total_facebook_likes']=(movie['actor_1_facebook_likes']+
                                      movie['actor_2_facebook_likes']+
                                      movie['actor_3_facebook_likes'])
movie['actor_total_facebook_likes']=movie['actor_total_facebook_likes'].fillna(0)
movie['is_cast_like_more']=(movie['cast_total_facebook_likes']>=movie['actor_total_facebook_likes'])
movie['is_cast_like_more'].all() #chech whether the bolean value is all true
#add a column
movie['pct_actor_cast_likes']=(movie['actor_total_facebook_likes']/movie['cast_total_facebook_likes'])
movie.set_index('movie_title')['pct_actor_cast_likes'].head()
#drop a column
#movie=movie.drop('actor_director_facebook_likes',axis='column')
#the drop defualts to drop rows by index name, in oprder to drop column, you must set the axis parameter to either 1 or columns.

#Alternative way to delete a colun is del movie['actor_director_facebook_likes']


#Insert Method, insert directly after column gross
profit_index=movie.columns.get_loc('gross')+1
profit_index
movie.insert(loc=profit_index,column='profit',value=movie['gross']-movie['budget'])
movie
# Out:
#                 color       director_name  num_critic_for_reviews  duration  \
# 0               Color       James Cameron                   723.0     178.0
# 1               Color      Gore Verbinski                   302.0     169.0
# 2               Color          Sam Mendes                   602.0     148.0
# 3               Color   Christopher Nolan                   813.0     164.0
# 4                 NaN         Doug Walker                     NaN       NaN
# 5               Color      Andrew Stanton                   462.0     132.0
# 6               Color           Sam Raimi                   392.0     156.0
# 7               Color        Nathan Greno                   324.0     100.0
# 8               Color         Joss Whedon                   635.0     141.0
# 9               Color         David Yates                   375.0     153.0
# 10              Color         Zack Snyder                   673.0     183.0
# ...
